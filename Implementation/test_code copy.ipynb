# %%
import tensorflow as tf
from tensorflow.keras import models,layers
import matplotlib.pyplot as plt

# %%
BATCH_SIZE = 32
IMAGE_SIZE = 128
CHANNEL = 3
EPOCHS = 20

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
directory=r'E:\Cutting Tool Paper\Dataset\cutting tool data\cwt images data',
seed=123,
shuffle = True,
image_size=(IMAGE_SIZE,IMAGE_SIZE),
batch_size = BATCH_SIZE
)
# Out:
# Found 320 files belonging to 4 classes.

# %%
class_names = dataset.class_names
class_names
# Out:
# ['Bearing Fault Data', 'Gear Fault Data', 'Normal Data', 'Tool Fault Data']

# %%
for image_batch,label_batch in dataset.take(1):
    print("Image Batch Shape : ", image_batch.shape)
    print("Single Image : ", image_batch[0])
    print("Label Image numpy : ", label_batch.numpy)
# Out:
# Image Batch Shape :  (32, 128, 128, 3)
# Single Image :  tf.Tensor(
# [[[255. 255. 255.]
#   [255. 255. 255.]
#   [255. 255. 255.]
#   ...
#   [255. 255. 255.]
#   [255. 255. 255.]
#   [255. 255. 255.]]
#
#  [[255. 255. 255.]
#   [255. 255. 255.]
#   [255. 255. 255.]
#   ...
#   [255. 255. 255.]
#   [255. 255. 255.]
#   [255. 255. 255.]]
#
#  [[255. 255. 255.]
#   [255. 255. 255.]
#   [255. 255. 255.]
#   ...
#   [255. 255. 255.]
#   [255. 255. 255.]
#   [255. 255. 255.]]
#
#  ...
#
#  [[255. 255. 255.]
#   [255. 255. 255.]
#   [255. 255. 255.]
#   ...
#   [255. 255. 255.]
#   [255. 255. 255.]
#   [255. 255. 255.]]
#
#  [[255. 255. 255.]
#   [255. 255. 255.]
#   [255. 255. 255.]
#   ...
#   [255. 255. 255.]
#   [255. 255. 255.]
#   [255. 255. 255.]]
#
#  [[255. 255. 255.]
#   [255. 255. 255.]
#   [255. 255. 255.]
#   ...
#   [255. 255. 255.]
#   [255. 255. 255.]
#   [255. 255. 255.]]], shape=(128, 128, 3), dtype=float32)
# Label Image numpy :  <bound method _EagerTensorBase.numpy of <tf.Tensor: shape=(32,), dtype=int32, numpy=
# array([2, 0, 0, 0, 3, 1, 1, 1, 3, 3, 1, 0, 0, 1, 0, 2, 3, 2, 2, 3, 0, 0,
#        2, 3, 0, 0, 3, 2, 3, 2, 1, 3])>>

# %%
len(class_names)
# Out:
# 4

# %%
plt.figure(figsize=(10, 10))
for image_batch, labels_batch in dataset.take(1):
    # Code to process the first batch of images and labels
    for i in range(12):
        ax = plt.subplot(3, 4, i + 1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(class_names[labels_batch[i]])
        plt.axis("off")

# %%
len(dataset)
# Out:
# 10

# %%
train_size = 0.8
len(dataset) * train_size
# Out:
# 8.0

# %%
train_ds = dataset.take(54)
len(train_ds)
# Out:
# 10

# %%
test_ds = dataset.skip(54)
len(test_ds)
# Out:
# 0

# %%
val_size = 0.1
len(dataset)*val_size
# Out:
# 1.0

# %%
val_ds = test_ds.take(6)
len(val_ds)
# Out:
# 0

# %%
test_ds = test_ds.skip(6)
len(test_ds)
# Out:
# 0

# %%
def get_dataset_partitions_tf(ds, train_split=0.8, val_split=0.1, test_split=0.1, shuffle=True, shuffle_size=10000):
    assert (train_split + test_split + val_split) == 1
    
    ds_size = len(ds)
    
    if shuffle:
        ds = ds.shuffle(shuffle_size, seed=12)
    
    train_size = int(train_split * ds_size)
    val_size = int(val_split * ds_size)
    
    train_ds = ds.take(train_size)    
    val_ds = ds.skip(train_size).take(val_size)
    test_ds = ds.skip(train_size).skip(val_size)
    
    return train_ds, val_ds, test_ds
train_ds, val_ds, test_ds = get_dataset_partitions_tf(dataset)

# %%
len(train_ds)
# Out:
# 8

# %%
len(val_ds)
# Out:
# 1

# %%
len(test_ds)
# Out:
# 1

# %%
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.preprocessing import image_dataset_from_directory

# Define the image size
IMAGE_SIZE = 128

# Create the resizing and rescaling preprocessing pipeline
resize_and_rescale = tf.keras.Sequential([
  layers.Resizing(IMAGE_SIZE, IMAGE_SIZE),
  layers.Rescaling(1./255),
])

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# Constants
BATCH_SIZE = 32
IMAGE_SIZE = 128
CHANNEL = 3
input_shape = (IMAGE_SIZE, IMAGE_SIZE, CHANNEL)
n_classes = 4

# Create the resizing and rescaling preprocessing pipeline
resize_and_rescale = tf.keras.Sequential([
    layers.Resizing(IMAGE_SIZE, IMAGE_SIZE),
    layers.Rescaling(1./255),
])

# Define the model
model = models.Sequential([
    layers.InputLayer(input_shape=input_shape),
    resize_and_rescale,
    layers.Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(64, kernel_size=(3, 3), activation='relu', padding='same'),
    layers.Conv2D(64, kernel_size=(3, 3), activation='relu', padding='same'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(128, kernel_size=(3, 3), activation='relu', padding='same'),
    layers.Conv2D(128, kernel_size=(3, 3), activation='relu', padding='same'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(256, kernel_size=(3, 3), activation='relu', padding='same'),
    layers.Conv2D(256, kernel_size=(3, 3), activation='relu', padding='same'),
    layers.MaxPooling2D((2, 2)),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dense(n_classes, activation='softmax'),
])

# Compile the model
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Summary of the model
model.summary()
# Out:
# C:\Users\Muhammad Umar\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\core\input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential_1 (Sequential)       │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 128, 128, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 64, 64, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 64, 64, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 32, 32, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 32, 32, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 16, 16, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 16, 16, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 8, 8, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 16384)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     2,097,280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │           516 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,260,804 (12.44 MB)
#  Trainable params: 3,260,804 (12.44 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(
    train_ds,
    validation_data=val_ds,
    batch_size=BATCH_SIZE,
    epochs=100,
    verbose=1
)
# Out:
# Epoch 1/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 493ms/step - accuracy: 0.1789 - loss: 1.4518 - val_accuracy: 0.2812 - val_loss: 1.3868
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 352ms/step - accuracy: 0.3155 - loss: 1.3867 - val_accuracy: 0.1562 - val_loss: 1.3858
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 353ms/step - accuracy: 0.2349 - loss: 1.3779 - val_accuracy: 0.2500 - val_loss: 1.3506
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 353ms/step - accuracy: 0.3880 - loss: 1.3186 - val_accuracy: 0.3750 - val_loss: 1.2814
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 358ms/step - accuracy: 0.3647 - loss: 1.3610 - val_accuracy: 0.2812 - val_loss: 1.3693
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 371ms/step - accuracy: 0.2744 - loss: 1.3687 - val_accuracy: 0.3750 - val_loss: 1.3480
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 429ms/step - accuracy: 0.3706 - loss: 1.3087 - val_accuracy: 0.4062 - val_loss: 1.2009
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 384ms/step - accuracy: 0.4787 - loss: 1.0918 - val_accuracy: 0.3750 - val_loss: 1.0195
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 379ms/step - accuracy: 0.4964 - loss: 0.9819 - val_accuracy: 0.4375 - val_loss: 0.9233
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 404ms/step - accuracy: 0.4414 - loss: 0.9666 - val_accuracy: 0.5000 - val_loss: 0.8360
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 371ms/step - accuracy: 0.5048 - loss: 0.8505 - val_accuracy: 0.5000 - val_loss: 0.7987
# Epoch 12/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 362ms/step - accuracy: 0.4805 - loss: 0.8452 - val_accuracy: 0.5000 - val_loss: 0.8196
# Epoch 13/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 361ms/step - accuracy: 0.5224 - loss: 0.8152 - val_accuracy: 0.5625 - val_loss: 0.7921
# Epoch 14/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 364ms/step - accuracy: 0.5035 - loss: 0.8644 - val_accuracy: 0.5625 - val_loss: 0.7774
# Epoch 15/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 380ms/step - accuracy: 0.4725 - loss: 0.8682 - val_accuracy: 0.4375 - val_loss: 0.8040
# Epoch 16/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 376ms/step - accuracy: 0.5151 - loss: 0.8136 - val_accuracy: 0.5000 - val_loss: 0.7924
# Epoch 17/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 402ms/step - accuracy: 0.5343 - loss: 0.7987 - val_accuracy: 0.5312 - val_loss: 0.7742
# Epoch 18/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 379ms/step - accuracy: 0.5528 - loss: 0.8271 - val_accuracy: 0.5000 - val_loss: 0.7808
# Epoch 19/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 359ms/step - accuracy: 0.4759 - loss: 0.8397 - val_accuracy: 0.5000 - val_loss: 0.7706
# Epoch 20/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 380ms/step - accuracy: 0.4901 - loss: 0.8369 - val_accuracy: 0.5000 - val_loss: 0.8296
# Epoch 21/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 370ms/step - accuracy: 0.4825 - loss: 0.8406 - val_accuracy: 0.5938 - val_loss: 0.7906
# Epoch 22/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 389ms/step - accuracy: 0.5250 - loss: 0.8471 - val_accuracy: 0.5625 - val_loss: 0.7743
# Epoch 23/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 355ms/step - accuracy: 0.5030 - loss: 0.8220 - val_accuracy: 0.5625 - val_loss: 0.7858
# Epoch 24/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 358ms/step - accuracy: 0.5323 - loss: 0.7679 - val_accuracy: 0.6250 - val_loss: 0.7763
# Epoch 25/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 358ms/step - accuracy: 0.5118 - loss: 0.8238 - val_accuracy: 0.5625 - val_loss: 0.7666
# Epoch 26/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 349ms/step - accuracy: 0.5506 - loss: 0.7974 - val_accuracy: 0.5000 - val_loss: 0.7877
# Epoch 27/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 355ms/step - accuracy: 0.4943 - loss: 0.8242 - val_accuracy: 0.5938 - val_loss: 0.7646
# Epoch 28/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 355ms/step - accuracy: 0.5274 - loss: 0.7835 - val_accuracy: 0.4688 - val_loss: 0.7853
# Epoch 29/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 355ms/step - accuracy: 0.5405 - loss: 0.8123 - val_accuracy: 0.6250 - val_loss: 0.7512
# Epoch 30/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 354ms/step - accuracy: 0.5309 - loss: 0.8179 - val_accuracy: 0.6250 - val_loss: 0.7490
# Epoch 31/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 354ms/step - accuracy: 0.5576 - loss: 0.7870 - val_accuracy: 0.5625 - val_loss: 0.7429
# Epoch 32/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 367ms/step - accuracy: 0.5520 - loss: 0.7661 - val_accuracy: 0.5000 - val_loss: 0.7827
# Epoch 33/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 382ms/step - accuracy: 0.5195 - loss: 0.8120 - val_accuracy: 0.5000 - val_loss: 0.8248
# Epoch 34/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 364ms/step - accuracy: 0.5251 - loss: 0.8202 - val_accuracy: 0.5625 - val_loss: 0.7731
# Epoch 35/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 368ms/step - accuracy: 0.5152 - loss: 0.8053 - val_accuracy: 0.6562 - val_loss: 0.7633
# Epoch 36/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 355ms/step - accuracy: 0.5425 - loss: 0.7681 - val_accuracy: 0.5000 - val_loss: 0.7811
# Epoch 37/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 357ms/step - accuracy: 0.5400 - loss: 0.8121 - val_accuracy: 0.5938 - val_loss: 0.7662
# Epoch 38/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 357ms/step - accuracy: 0.4846 - loss: 0.8086 - val_accuracy: 0.5938 - val_loss: 0.7293
# Epoch 39/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 358ms/step - accuracy: 0.5219 - loss: 0.8003 - val_accuracy: 0.6250 - val_loss: 0.7452
# Epoch 40/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 368ms/step - accuracy: 0.5538 - loss: 0.8196 - val_accuracy: 0.5938 - val_loss: 0.7351
# Epoch 41/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 356ms/step - accuracy: 0.5450 - loss: 0.7768 - val_accuracy: 0.5625 - val_loss: 0.7385
# Epoch 42/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 369ms/step - accuracy: 0.5682 - loss: 0.8367 - val_accuracy: 0.5625 - val_loss: 0.7879
# Epoch 43/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 371ms/step - accuracy: 0.5046 - loss: 0.8513 - val_accuracy: 0.5625 - val_loss: 0.7869
# Epoch 44/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 402ms/step - accuracy: 0.5451 - loss: 0.7877 - val_accuracy: 0.5312 - val_loss: 0.7949
# Epoch 45/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 366ms/step - accuracy: 0.5312 - loss: 0.8263 - val_accuracy: 0.5938 - val_loss: 0.7492
# Epoch 46/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 371ms/step - accuracy: 0.6069 - loss: 0.7729 - val_accuracy: 0.5312 - val_loss: 0.7558
# Epoch 47/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 356ms/step - accuracy: 0.5037 - loss: 0.8396 - val_accuracy: 0.5625 - val_loss: 0.8074
# Epoch 48/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 364ms/step - accuracy: 0.5818 - loss: 0.7926 - val_accuracy: 0.5938 - val_loss: 0.7425
# Epoch 49/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 383ms/step - accuracy: 0.5280 - loss: 0.8245 - val_accuracy: 0.4375 - val_loss: 0.8437
# Epoch 50/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 411ms/step - accuracy: 0.5227 - loss: 0.8265 - val_accuracy: 0.6562 - val_loss: 0.7528
# Epoch 51/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 405ms/step - accuracy: 0.5494 - loss: 0.7770 - val_accuracy: 0.5938 - val_loss: 0.7376
# Epoch 52/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 414ms/step - accuracy: 0.5572 - loss: 0.7790 - val_accuracy: 0.5000 - val_loss: 0.8129
# Epoch 53/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 360ms/step - accuracy: 0.5595 - loss: 0.7677 - val_accuracy: 0.5938 - val_loss: 0.6916
# Epoch 54/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 423ms/step - accuracy: 0.5513 - loss: 0.7338 - val_accuracy: 0.4688 - val_loss: 0.8743
# Epoch 55/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 391ms/step - accuracy: 0.6448 - loss: 0.6695 - val_accuracy: 0.6875 - val_loss: 0.7724
# Epoch 56/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 448ms/step - accuracy: 0.5664 - loss: 0.8076 - val_accuracy: 0.5312 - val_loss: 0.7697
# Epoch 57/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 427ms/step - accuracy: 0.5731 - loss: 0.7356 - val_accuracy: 0.5312 - val_loss: 0.7758
# Epoch 58/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 370ms/step - accuracy: 0.6680 - loss: 0.6814 - val_accuracy: 0.6562 - val_loss: 0.7208
# Epoch 59/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 377ms/step - accuracy: 0.5912 - loss: 0.7651 - val_accuracy: 0.5938 - val_loss: 0.8055
# Epoch 60/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 378ms/step - accuracy: 0.6161 - loss: 0.7085 - val_accuracy: 0.5625 - val_loss: 0.8049
# Epoch 61/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 366ms/step - accuracy: 0.6170 - loss: 0.7292 - val_accuracy: 0.5000 - val_loss: 0.8930
# Epoch 62/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 380ms/step - accuracy: 0.6458 - loss: 0.6912 - val_accuracy: 0.6250 - val_loss: 0.7141
# Epoch 63/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 367ms/step - accuracy: 0.6004 - loss: 0.7498 - val_accuracy: 0.5000 - val_loss: 0.8243
# Epoch 64/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 369ms/step - accuracy: 0.6754 - loss: 0.6353 - val_accuracy: 0.5625 - val_loss: 0.7363
# Epoch 65/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 381ms/step - accuracy: 0.6286 - loss: 0.6814 - val_accuracy: 0.6562 - val_loss: 0.8057
# Epoch 66/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 359ms/step - accuracy: 0.6757 - loss: 0.6575 - val_accuracy: 0.6250 - val_loss: 0.7144
# Epoch 67/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 353ms/step - accuracy: 0.6293 - loss: 0.6203 - val_accuracy: 0.6562 - val_loss: 0.7795
# Epoch 68/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 364ms/step - accuracy: 0.6819 - loss: 0.5853 - val_accuracy: 0.6875 - val_loss: 0.8128
# Epoch 69/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 371ms/step - accuracy: 0.6638 - loss: 0.5540 - val_accuracy: 0.6562 - val_loss: 0.7122
# Epoch 70/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 375ms/step - accuracy: 0.7505 - loss: 0.5397 - val_accuracy: 0.5938 - val_loss: 0.7513
# Epoch 71/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 372ms/step - accuracy: 0.7473 - loss: 0.4981 - val_accuracy: 0.6875 - val_loss: 0.5952
# Epoch 72/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 376ms/step - accuracy: 0.7434 - loss: 0.4869 - val_accuracy: 0.6250 - val_loss: 0.6066
# Epoch 73/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 360ms/step - accuracy: 0.7410 - loss: 0.4425 - val_accuracy: 0.7188 - val_loss: 0.6934
# Epoch 74/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 369ms/step - accuracy: 0.7248 - loss: 0.4784 - val_accuracy: 0.6875 - val_loss: 0.8106
# Epoch 75/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 370ms/step - accuracy: 0.7373 - loss: 0.4247 - val_accuracy: 0.6875 - val_loss: 0.7631
# Epoch 76/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 362ms/step - accuracy: 0.7192 - loss: 0.4371 - val_accuracy: 0.6562 - val_loss: 0.8477
# Epoch 77/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 381ms/step - accuracy: 0.7535 - loss: 0.4100 - val_accuracy: 0.6875 - val_loss: 0.8559
# Epoch 78/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 392ms/step - accuracy: 0.7344 - loss: 0.4101 - val_accuracy: 0.6875 - val_loss: 0.8241
# Epoch 79/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 373ms/step - accuracy: 0.7678 - loss: 0.4356 - val_accuracy: 0.6875 - val_loss: 0.8731
# Epoch 80/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 377ms/step - accuracy: 0.7102 - loss: 0.4539 - val_accuracy: 0.6875 - val_loss: 0.7537
# Epoch 81/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 431ms/step - accuracy: 0.7332 - loss: 0.4405 - val_accuracy: 0.6562 - val_loss: 0.8815
# Epoch 82/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 426ms/step - accuracy: 0.7473 - loss: 0.4162 - val_accuracy: 0.5938 - val_loss: 0.6779
# Epoch 83/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 422ms/step - accuracy: 0.7093 - loss: 0.4969 - val_accuracy: 0.7188 - val_loss: 0.8661
# Epoch 84/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 378ms/step - accuracy: 0.6926 - loss: 0.4864 - val_accuracy: 0.7188 - val_loss: 0.7703
# Epoch 85/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 380ms/step - accuracy: 0.7686 - loss: 0.4426 - val_accuracy: 0.6875 - val_loss: 0.9983
# Epoch 86/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 371ms/step - accuracy: 0.7662 - loss: 0.4294 - val_accuracy: 0.6875 - val_loss: 0.8978
# Epoch 87/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 362ms/step - accuracy: 0.7784 - loss: 0.4075 - val_accuracy: 0.6875 - val_loss: 0.9075
# Epoch 88/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 393ms/step - accuracy: 0.7493 - loss: 0.4337 - val_accuracy: 0.6875 - val_loss: 0.7456
# Epoch 89/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 380ms/step - accuracy: 0.7536 - loss: 0.4204 - val_accuracy: 0.6562 - val_loss: 0.9494
# Epoch 90/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 403ms/step - accuracy: 0.7471 - loss: 0.4216 - val_accuracy: 0.7500 - val_loss: 0.8823
# Epoch 91/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 368ms/step - accuracy: 0.7668 - loss: 0.3990 - val_accuracy: 0.7500 - val_loss: 0.8040
# Epoch 92/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 367ms/step - accuracy: 0.8017 - loss: 0.3910 - val_accuracy: 0.6562 - val_loss: 0.7820
# Epoch 93/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 372ms/step - accuracy: 0.7658 - loss: 0.4309 - val_accuracy: 0.6250 - val_loss: 1.0774
# Epoch 94/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 362ms/step - accuracy: 0.7851 - loss: 0.4016 - val_accuracy: 0.7188 - val_loss: 0.7792
# Epoch 95/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 369ms/step - accuracy: 0.7633 - loss: 0.4145 - val_accuracy: 0.7188 - val_loss: 0.8112
# Epoch 96/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 366ms/step - accuracy: 0.7922 - loss: 0.3688 - val_accuracy: 0.7188 - val_loss: 0.8838
# Epoch 97/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 368ms/step - accuracy: 0.7713 - loss: 0.4273 - val_accuracy: 0.7812 - val_loss: 0.8318
# Epoch 98/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 363ms/step - accuracy: 0.7597 - loss: 0.4140 - val_accuracy: 0.7188 - val_loss: 0.8569
# Epoch 99/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 371ms/step - accuracy: 0.7677 - loss: 0.4232 - val_accuracy: 0.6875 - val_loss: 0.8891
# Epoch 100/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 384ms/step - accuracy: 0.7881 - loss: 0.3939 - val_accuracy: 0.6875 - val_loss: 0.9270

# %%
scores = model.evaluate(test_ds)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.6250 - loss: 1.4510

# %%
print(history)
print(history.params)
print(history.history.keys())
# Out:
# <keras.src.callbacks.history.History object at 0x000001E16AE7A890>
# {'verbose': 1, 'epochs': 100, 'steps': 8}
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
import matplotlib.pyplot as plt

# Get training accuracy values
acc = history.history['accuracy']

# Plot training accuracy
plt.figure(figsize=(8, 6))
plt.plot(acc, label='Training Accuracy')
plt.title('Training Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
import numpy as np

# Get predictions
val_pred = np.argmax(model.predict(val_ds), axis=-1)
val_true = np.concatenate([y for x, y in val_ds], axis=0)  # assuming val_ds is a tf.data.Dataset
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Compute confusion matrix
conf_mat = confusion_matrix(val_pred, val_pred)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_mat, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Class 0', 'Class 1', 'Class 2', 'Class 3'],
            yticklabels=['Class 0', 'Class 1', 'Class 2', 'Class 3'])
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()
